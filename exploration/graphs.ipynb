# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Book1.csv')
for col in df:
    df[col]= df[col].values.astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gender    367 non-null    object
#  1   age       367 non-null    object
#  2   f-edu     367 non-null    object
#  3   m-edu     367 non-null    object
#  4   income    367 non-null    object
#  5   event     367 non-null    object
#  6   duration  367 non-null    object
#  7   p1        367 non-null    object
#  8   p2        367 non-null    object
#  9   p3        367 non-null    object
#  10  p4        367 non-null    object
#  11  p5        367 non-null    object
#  12  s1        367 non-null    object
#  13  s2        367 non-null    object
#  14  s3        367 non-null    object
#  15  s4        367 non-null    object
#  16  s5        367 non-null    object
#  17  c1        367 non-null    object
#  18  c2        367 non-null    object
#  19  c3        367 non-null    object
#  20  c4        367 non-null    object
#  21  c5        367 non-null    object
#  22  e1        367 non-null    object
#  23  e2        367 non-null    object
#  24  e3        367 non-null    object
#  25  e4        367 non-null    object
#  26  e5        367 non-null    object
# dtypes: object(27)
# memory usage: 77.5+ KB

# %%
df.columns
# Out:
# Index(['gender', 'age', 'f-edu', 'm-edu', 'income', 'event', 'duration', 'p1',
#        'p2', 'p3', 'p4', 'p5', 's1', 's2', 's3', 's4', 's5', 'c1', 'c2', 'c3',
#        'c4', 'c5', 'e1', 'e2', 'e3', 'e4', 'e5'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
# ['layer', 'stack', 'fill', 'dodge']
sns.histplot(data = df, x = 'income', hue='event', stat='count', multiple='stack', hue_order=['0','1'], shrink=0.8)
plt.xlabel('Monthly household income')
plt.xticks(rotation=40)
plt.show()

# %%
sns.histplot(data = df, x = 'gender', hue='event',  multiple="stack", hue_order=['0', '1'], shrink=0.5)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df, x='age', hue='event', stat='count', multiple='stack', hue_order=['0','1'], shrink=0.8)
plt.xlabel('Age of students')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(y="f-edu", data=df, color='c')
plt.title('Father educational attainment')
plt.ylabel("")
plt.show()

# %%
sns.countplot(y="m-edu", data=df, color="c")
plt.title('Mother educational attainment')
plt.ylabel("")
plt.show()
